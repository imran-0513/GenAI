# %%
import openai

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
# import pandas as pd

# %%
## list out openai models

openai.Model.list()['data']
# Out:
# [<Model model id=text-search-babbage-doc-001 at 0x456c418> JSON: {
#    "id": "text-search-babbage-doc-001",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=gpt-3.5-turbo-16k-0613 at 0x80d7058> JSON: {
#    "id": "gpt-3.5-turbo-16k-0613",
#    "object": "model",
#    "created": 1685474247,
#    "owned_by": "openai"
#  },
#  <Model model id=curie-search-query at 0x80d7088> JSON: {
#    "id": "curie-search-query",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=gpt-3.5-turbo-16k at 0x80d70b8> JSON: {
#    "id": "gpt-3.5-turbo-16k",
#    "object": "model",
#    "created": 1683758102,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=text-search-babbage-query-001 at 0x80d70e8> JSON: {
#    "id": "text-search-babbage-query-001",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=babbage at 0x80d7118> JSON: {
#    "id": "babbage",
#    "object": "model",
#    "created": 1649358449,
#    "owned_by": "openai"
#  },
#  <Model model id=babbage-search-query at 0x80d7148> JSON: {
#    "id": "babbage-search-query",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-babbage-001 at 0x80d7178> JSON: {
#    "id": "text-babbage-001",
#    "object": "model",
#    "created": 1649364043,
#    "owned_by": "openai"
#  },
#  <Model model id=text-similarity-davinci-001 at 0x80d71a8> JSON: {
#    "id": "text-similarity-davinci-001",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=davinci-similarity at 0x80d71d8> JSON: {
#    "id": "davinci-similarity",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=code-davinci-edit-001 at 0x80d7208> JSON: {
#    "id": "code-davinci-edit-001",
#    "object": "model",
#    "created": 1649880484,
#    "owned_by": "openai"
#  },
#  <Model model id=curie-similarity at 0x80d7238> JSON: {
#    "id": "curie-similarity",
#    "object": "model",
#    "created": 1651172510,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=babbage-search-document at 0x80d7268> JSON: {
#    "id": "babbage-search-document",
#    "object": "model",
#    "created": 1651172510,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=curie-instruct-beta at 0x80d7298> JSON: {
#    "id": "curie-instruct-beta",
#    "object": "model",
#    "created": 1649364042,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-3.5-turbo at 0x80d72c8> JSON: {
#    "id": "gpt-3.5-turbo",
#    "object": "model",
#    "created": 1677610602,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-3.5-turbo-1106 at 0x80d72f8> JSON: {
#    "id": "gpt-3.5-turbo-1106",
#    "object": "model",
#    "created": 1698959748,
#    "owned_by": "system"
#  },
#  <Model model id=text-search-ada-doc-001 at 0x80d7328> JSON: {
#    "id": "text-search-ada-doc-001",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=davinci-instruct-beta at 0x80d7358> JSON: {
#    "id": "davinci-instruct-beta",
#    "object": "model",
#    "created": 1649364042,
#    "owned_by": "openai"
#  },
#  <Model model id=text-similarity-babbage-001 at 0x80d7388> JSON: {
#    "id": "text-similarity-babbage-001",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-search-davinci-doc-001 at 0x80d73b8> JSON: {
#    "id": "text-search-davinci-doc-001",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=babbage-similarity at 0x80d73e8> JSON: {
#    "id": "babbage-similarity",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-embedding-ada-002 at 0x80d7418> JSON: {
#    "id": "text-embedding-ada-002",
#    "object": "model",
#    "created": 1671217299,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=davinci-search-query at 0x80d7448> JSON: {
#    "id": "davinci-search-query",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-similarity-curie-001 at 0x80d7478> JSON: {
#    "id": "text-similarity-curie-001",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-davinci-001 at 0x80d74a8> JSON: {
#    "id": "text-davinci-001",
#    "object": "model",
#    "created": 1649364042,
#    "owned_by": "openai"
#  },
#  <Model model id=text-search-davinci-query-001 at 0x80d74d8> JSON: {
#    "id": "text-search-davinci-query-001",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=ada-search-document at 0x80d7508> JSON: {
#    "id": "ada-search-document",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=ada-code-search-code at 0x80d7538> JSON: {
#    "id": "ada-code-search-code",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=babbage-002 at 0x80d7568> JSON: {
#    "id": "babbage-002",
#    "object": "model",
#    "created": 1692634615,
#    "owned_by": "system"
#  },
#  <Model model id=davinci-002 at 0x80d7598> JSON: {
#    "id": "davinci-002",
#    "object": "model",
#    "created": 1692634301,
#    "owned_by": "system"
#  },
#  <Model model id=davinci-search-document at 0x80d75c8> JSON: {
#    "id": "davinci-search-document",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=curie-search-document at 0x80d75f8> JSON: {
#    "id": "curie-search-document",
#    "object": "model",
#    "created": 1651172508,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=babbage-code-search-code at 0x80d7628> JSON: {
#    "id": "babbage-code-search-code",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-search-ada-query-001 at 0x80d7688> JSON: {
#    "id": "text-search-ada-query-001",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=code-search-ada-text-001 at 0x80d7658> JSON: {
#    "id": "code-search-ada-text-001",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=babbage-code-search-text at 0x80d76b8> JSON: {
#    "id": "babbage-code-search-text",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=code-search-babbage-code-001 at 0x80d76e8> JSON: {
#    "id": "code-search-babbage-code-001",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=ada-search-query at 0x80d7718> JSON: {
#    "id": "ada-search-query",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=ada-code-search-text at 0x80d7748> JSON: {
#    "id": "ada-code-search-text",
#    "object": "model",
#    "created": 1651172510,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=tts-1-hd at 0x80d7778> JSON: {
#    "id": "tts-1-hd",
#    "object": "model",
#    "created": 1699046015,
#    "owned_by": "system"
#  },
#  <Model model id=text-search-curie-query-001 at 0x80d77a8> JSON: {
#    "id": "text-search-curie-query-001",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-davinci-002 at 0x80d77d8> JSON: {
#    "id": "text-davinci-002",
#    "object": "model",
#    "created": 1649880484,
#    "owned_by": "openai"
#  },
#  <Model model id=text-davinci-edit-001 at 0x80d7808> JSON: {
#    "id": "text-davinci-edit-001",
#    "object": "model",
#    "created": 1649809179,
#    "owned_by": "openai"
#  },
#  <Model model id=code-search-babbage-text-001 at 0x80d7838> JSON: {
#    "id": "code-search-babbage-text-001",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=tts-1-hd-1106 at 0x80d7868> JSON: {
#    "id": "tts-1-hd-1106",
#    "object": "model",
#    "created": 1699053533,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-3.5-turbo-instruct-0914 at 0x80d7898> JSON: {
#    "id": "gpt-3.5-turbo-instruct-0914",
#    "object": "model",
#    "created": 1694122472,
#    "owned_by": "system"
#  },
#  <Model model id=ada at 0x80d78c8> JSON: {
#    "id": "ada",
#    "object": "model",
#    "created": 1649357491,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-3.5-turbo-0613 at 0x80d78f8> JSON: {
#    "id": "gpt-3.5-turbo-0613",
#    "object": "model",
#    "created": 1686587434,
#    "owned_by": "openai"
#  },
#  <Model model id=text-ada-001 at 0x80d7928> JSON: {
#    "id": "text-ada-001",
#    "object": "model",
#    "created": 1649364042,
#    "owned_by": "openai"
#  },
#  <Model model id=ada-similarity at 0x80d7958> JSON: {
#    "id": "ada-similarity",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=code-search-ada-code-001 at 0x80d7988> JSON: {
#    "id": "code-search-ada-code-001",
#    "object": "model",
#    "created": 1651172507,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-similarity-ada-001 at 0x80d79b8> JSON: {
#    "id": "text-similarity-ada-001",
#    "object": "model",
#    "created": 1651172505,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=gpt-3.5-turbo-0301 at 0x80d79e8> JSON: {
#    "id": "gpt-3.5-turbo-0301",
#    "object": "model",
#    "created": 1677649963,
#    "owned_by": "openai"
#  },
#  <Model model id=gpt-3.5-turbo-instruct at 0x80d7a18> JSON: {
#    "id": "gpt-3.5-turbo-instruct",
#    "object": "model",
#    "created": 1692901427,
#    "owned_by": "system"
#  },
#  <Model model id=text-search-curie-doc-001 at 0x80d7a48> JSON: {
#    "id": "text-search-curie-doc-001",
#    "object": "model",
#    "created": 1651172509,
#    "owned_by": "openai-dev"
#  },
#  <Model model id=text-davinci-003 at 0x80d7a78> JSON: {
#    "id": "text-davinci-003",
#    "object": "model",
#    "created": 1669599635,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=text-curie-001 at 0x80d7aa8> JSON: {
#    "id": "text-curie-001",
#    "object": "model",
#    "created": 1649364043,
#    "owned_by": "openai"
#  },
#  <Model model id=whisper-1 at 0x80d7b08> JSON: {
#    "id": "whisper-1",
#    "object": "model",
#    "created": 1677532384,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=curie at 0x80d7b68> JSON: {
#    "id": "curie",
#    "object": "model",
#    "created": 1649359874,
#    "owned_by": "openai"
#  },
#  <Model model id=canary-tts at 0x80d7bf8> JSON: {
#    "id": "canary-tts",
#    "object": "model",
#    "created": 1699492935,
#    "owned_by": "system"
#  },
#  <Model model id=tts-1 at 0x80d7c88> JSON: {
#    "id": "tts-1",
#    "object": "model",
#    "created": 1681940951,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=davinci at 0x80d7c58> JSON: {
#    "id": "davinci",
#    "object": "model",
#    "created": 1649359874,
#    "owned_by": "openai"
#  },
#  <Model model id=dall-e-2 at 0x80d7cb8> JSON: {
#    "id": "dall-e-2",
#    "object": "model",
#    "created": 1698798177,
#    "owned_by": "system"
#  },
#  <Model model id=tts-1-1106 at 0x80d7ce8> JSON: {
#    "id": "tts-1-1106",
#    "object": "model",
#    "created": 1699053241,
#    "owned_by": "system"
#  },
#  <Model model id=dall-e-3 at 0x80d7d18> JSON: {
#    "id": "dall-e-3",
#    "object": "model",
#    "created": 1698785189,
#    "owned_by": "system"
#  }]

# %%
## Chat completion API and Completion API

# %%
## will start with Completion API

openai.Completion.create(

    model = 'text-curie-001',
    prompt  = 'what is the capital of india?'
    

)
# Out:
# <OpenAIObject text_completion id=cmpl-8JEugioZS12ueY3RtGMxt4TZB2x1W at 0x80edb08> JSON: {
#   "warning": "This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations",
#   "id": "cmpl-8JEugioZS12ueY3RtGMxt4TZB2x1W",
#   "object": "text_completion",
#   "created": 1699596250,
#   "model": "text-curie-001",
#   "choices": [
#     {
#       "text": "\n\nThe capital of India is New Delhi.",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 8,
#     "completion_tokens": 10,
#     "total_tokens": 18
#   }
# }

# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        # temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
text = f"""
You should express what you want a model to do by \ 
# providing instructions that are as clear and \
specific as you can possibly make them. \ 
This will guide the model towards the desired output, \ 
and reduce the chances of receiving irrelevant \ 
or incorrect responses. Don't confuse writing a \ 
clear prompt with writing a short prompt. \ 
In many cases, longer prompts provide more clarity \ 
and context for the model, which can lead to \ 
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \ 
not into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# The text emphasizes the importance of providing clear and specific instructions for models in order to achieve the desired output. It advises against confusing clear prompts with short prompts and suggests that longer prompts can offer more clarity and context, resulting in more detailed and relevant responses.
